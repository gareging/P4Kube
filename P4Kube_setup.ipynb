# %%
# Initializing the project and the keys
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager
import json
import traceback

# Update this line to specify your project id
project_id = "5f00e1ce-d082-4a2b-b08f-889658e932b7"

fablib = fablib_manager(project_id=project_id)

#fablib.show_config()

fablib.verify_and_configure()
# !chmod 0600 fabric_config/fabric_bastion_key
# !chmod 0600 fabric_config/slice_key
# Out:
# User: grigoryan@alfred.edu bastion key is valid!
# Configuration is valid
# User: grigoryan@alfred.edu bastion key is valid!
# Configuration is valid
# Please save the config!

# %%
# Reinitializing the slice or creating a new slice (choose the site and the corresponding string it below)
slice_name = 'My_P4Kube_slice_2' 
try:
    # Reinitializes the existing slice
    slice = fablib.get_slice(slice_name)
    slice.list_nodes()
    print('Done retrieving the existing slice')
except:
    print(f'Creating a new slice {slice_name}')
    slice = fablib.new_slice(name=slice_name)
    vm_names = ['p4switch', 'master', 'client'] + [f'node{i}' for i in range(1, 11)]
    for vm_name in vm_names:
        node = slice.add_node(name=vm_name, site='RUTG', image='default_ubuntu_20')
        node.set_capacities(cores=2, ram=6, disk=10)
        node.add_component(model='NIC_Basic', name='if1')
    
    # Add additional NICs to p4switch (if2 to if12)
    p4_node = slice.get_node('p4switch')
    for i in range(2, 13):
        p4_node.add_component(model='NIC_Basic', name=f'if{i}')
    
    # Add L2 bridges (ms, cs, n1s-n6s)
    bridge_names = ['ms', 'cs'] + [f'n{i}s' for i in range(1, 11)]
    bridges = {}
    for br in bridge_names:
        bridges[br] = slice.add_l2network(name=br)
    
    # Connect master-if1 and p4switch-if1 to 'ms'
    bridges['ms'].add_interface(slice.get_node('p4switch').get_interface('p4switch-if1-p1'))
    bridges['ms'].add_interface(slice.get_node('master').get_interface('master-if1-p1'))
    
    # Connect client-if1 and p4switch-if2 to 'cs'
    bridges['cs'].add_interface(p4_node.get_interface('p4switch-if2-p1'))
    bridges['cs'].add_interface(slice.get_node('client').get_interface('client-if1-p1'))
    
    # Connect nodes to p4switch
    for i in range(1, 11):
        node = slice.get_node(f'node{i}')
        bridges[f'n{i}s'].add_interface(node.get_interface(f'node{i}-if1-p1'))
        bridges[f'n{i}s'].add_interface(p4_node.get_interface(f'p4switch-if{i+2}-p1'))

    # Submit the slice
    slice.submit()
    print(f"Slice '{slice_name}' created and submitted.")
# Out:
# <style type="text/css">
# #T_36b86 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_36b86 th {
#   text-align: left;
# }
# #T_36b86 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_36b86 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_36b86 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_36b86_row0_col0, #T_36b86_row0_col1, #T_36b86_row0_col2, #T_36b86_row0_col3, #T_36b86_row0_col4, #T_36b86_row0_col5, #T_36b86_row0_col6, #T_36b86_row0_col7, #T_36b86_row0_col8, #T_36b86_row0_col9, #T_36b86_row0_col10, #T_36b86_row0_col11, #T_36b86_row0_col12, #T_36b86_row0_col13, #T_36b86_row0_col14, #T_36b86_row0_col15, #T_36b86_row1_col0, #T_36b86_row1_col1, #T_36b86_row1_col2, #T_36b86_row1_col3, #T_36b86_row1_col4, #T_36b86_row1_col5, #T_36b86_row1_col6, #T_36b86_row1_col7, #T_36b86_row1_col8, #T_36b86_row1_col9, #T_36b86_row1_col10, #T_36b86_row1_col11, #T_36b86_row1_col12, #T_36b86_row1_col13, #T_36b86_row1_col14, #T_36b86_row1_col15, #T_36b86_row2_col0, #T_36b86_row2_col1, #T_36b86_row2_col2, #T_36b86_row2_col3, #T_36b86_row2_col4, #T_36b86_row2_col5, #T_36b86_row2_col6, #T_36b86_row2_col7, #T_36b86_row2_col8, #T_36b86_row2_col9, #T_36b86_row2_col10, #T_36b86_row2_col11, #T_36b86_row2_col12, #T_36b86_row2_col13, #T_36b86_row2_col14, #T_36b86_row2_col15, #T_36b86_row3_col0, #T_36b86_row3_col1, #T_36b86_row3_col2, #T_36b86_row3_col3, #T_36b86_row3_col4, #T_36b86_row3_col5, #T_36b86_row3_col6, #T_36b86_row3_col7, #T_36b86_row3_col8, #T_36b86_row3_col9, #T_36b86_row3_col10, #T_36b86_row3_col11, #T_36b86_row3_col12, #T_36b86_row3_col13, #T_36b86_row3_col14, #T_36b86_row3_col15, #T_36b86_row4_col0, #T_36b86_row4_col1, #T_36b86_row4_col2, #T_36b86_row4_col3, #T_36b86_row4_col4, #T_36b86_row4_col5, #T_36b86_row4_col6, #T_36b86_row4_col7, #T_36b86_row4_col8, #T_36b86_row4_col9, #T_36b86_row4_col10, #T_36b86_row4_col11, #T_36b86_row4_col12, #T_36b86_row4_col13, #T_36b86_row4_col14, #T_36b86_row4_col15, #T_36b86_row5_col0, #T_36b86_row5_col1, #T_36b86_row5_col2, #T_36b86_row5_col3, #T_36b86_row5_col4, #T_36b86_row5_col5, #T_36b86_row5_col6, #T_36b86_row5_col7, #T_36b86_row5_col8, #T_36b86_row5_col9, #T_36b86_row5_col10, #T_36b86_row5_col11, #T_36b86_row5_col12, #T_36b86_row5_col13, #T_36b86_row5_col14, #T_36b86_row5_col15, #T_36b86_row6_col0, #T_36b86_row6_col1, #T_36b86_row6_col2, #T_36b86_row6_col3, #T_36b86_row6_col4, #T_36b86_row6_col5, #T_36b86_row6_col6, #T_36b86_row6_col7, #T_36b86_row6_col8, #T_36b86_row6_col9, #T_36b86_row6_col10, #T_36b86_row6_col11, #T_36b86_row6_col12, #T_36b86_row6_col13, #T_36b86_row6_col14, #T_36b86_row6_col15, #T_36b86_row7_col0, #T_36b86_row7_col1, #T_36b86_row7_col2, #T_36b86_row7_col3, #T_36b86_row7_col4, #T_36b86_row7_col5, #T_36b86_row7_col6, #T_36b86_row7_col7, #T_36b86_row7_col8, #T_36b86_row7_col9, #T_36b86_row7_col10, #T_36b86_row7_col11, #T_36b86_row7_col12, #T_36b86_row7_col13, #T_36b86_row7_col14, #T_36b86_row7_col15, #T_36b86_row8_col0, #T_36b86_row8_col1, #T_36b86_row8_col2, #T_36b86_row8_col3, #T_36b86_row8_col4, #T_36b86_row8_col5, #T_36b86_row8_col6, #T_36b86_row8_col7, #T_36b86_row8_col8, #T_36b86_row8_col9, #T_36b86_row8_col10, #T_36b86_row8_col11, #T_36b86_row8_col12, #T_36b86_row8_col13, #T_36b86_row8_col14, #T_36b86_row8_col15, #T_36b86_row9_col0, #T_36b86_row9_col1, #T_36b86_row9_col2, #T_36b86_row9_col3, #T_36b86_row9_col4, #T_36b86_row9_col5, #T_36b86_row9_col6, #T_36b86_row9_col7, #T_36b86_row9_col8, #T_36b86_row9_col9, #T_36b86_row9_col10, #T_36b86_row9_col11, #T_36b86_row9_col12, #T_36b86_row9_col13, #T_36b86_row9_col14, #T_36b86_row9_col15, #T_36b86_row10_col0, #T_36b86_row10_col1, #T_36b86_row10_col2, #T_36b86_row10_col3, #T_36b86_row10_col4, #T_36b86_row10_col5, #T_36b86_row10_col6, #T_36b86_row10_col7, #T_36b86_row10_col8, #T_36b86_row10_col9, #T_36b86_row10_col10, #T_36b86_row10_col11, #T_36b86_row10_col12, #T_36b86_row10_col13, #T_36b86_row10_col14, #T_36b86_row10_col15, #T_36b86_row11_col0, #T_36b86_row11_col1, #T_36b86_row11_col2, #T_36b86_row11_col3, #T_36b86_row11_col4, #T_36b86_row11_col5, #T_36b86_row11_col6, #T_36b86_row11_col7, #T_36b86_row11_col8, #T_36b86_row11_col9, #T_36b86_row11_col10, #T_36b86_row11_col11, #T_36b86_row11_col12, #T_36b86_row11_col13, #T_36b86_row11_col14, #T_36b86_row11_col15, #T_36b86_row12_col0, #T_36b86_row12_col1, #T_36b86_row12 ...
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_36b86">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_36b86_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_36b86_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_36b86_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_36b86_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_36b86_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_36b86_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_36b86_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_36b86_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_36b86_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_36b86_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_36b86_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_36b86_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_36b86_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_36b86_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_36b86_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_36b86_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_36b86_row0_col0" class="data row0 col0" >40b7b662-d8ca-4eb5-803d-723c8a49aa01</td>
#       <td id="T_36b86_row0_col1" class="data row0 col1" >client</td>
#       <td id="T_36b86_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_36b86_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_36b86_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_36b86_row0_col5" class="data row0 col5" >default_ubuntu_20</td>
#       <td id="T_36b86_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_36b86_row0_col7" class="data row0 col7" >rutg-w4.fabric-testbed.net</td>
#       <td id="T_36b86_row0_col8" class="data row0 col8" >RUTG</td>
#       <td id="T_36b86_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_36b86_row0_col10" class="data row0 col10" >2620:0:d61:4101:f816:3eff:fef8:983d</td>
#       <td id="T_36b86_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_36b86_row0_col12" class="data row0 col12" ></td>
#       <td id="T_36b86_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2620:0:d61:4101:f816:3eff:fef8:983d</td>
#       <td id="T_36b86_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_36b86_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_36b86_row1_col0" class="data row1 col0" >4bdb780d-1a28-4464-9f72-38a30c27f0d9</td>
#       <td id="T_36b86_row1_col1" class="data row1 col1" >master</td>
#       <td id="T_36b86_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_36b86_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_36b86_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_36b86_row1_col5" class="d
# Done retrieving the existing slice

# %%
print('Changing the mac addresses of all nodes, master and client to match with the controller program')
mac_map = {
    'master':  '5E:00:00:00:00:01',
    'node1':   '5E:00:00:00:00:02',
    'node2':   '5E:00:00:00:00:03',
    'node3':   '5E:00:00:00:00:04',
    'node4':   '5E:00:00:00:00:05',
    'node5':   '5E:00:00:00:00:06',
    'node6':   '5E:00:00:00:00:07',
    'node7':   '5E:00:00:00:00:08',
    'node8':   '5E:00:00:00:00:09',
    'node9':   '5E:00:00:00:00:10',
    'node10':  '5E:00:00:00:00:11',
    'client':  '5E:00:00:00:00:12'
}

# Configuring the routing on the nodes
for node_name in ['master'] + [f'node{i}' for i in range(1, 11)] + ['client']:
    node = slice.get_node(node_name)
    mac = mac_map[node_name]
    if node_name == 'master':
        index = 10
    elif node_name == 'client':
        index = 21
    else:
        index = 10+int(node_name[4:])

    ip = f'{index}.0.0.2/24'
    gw = f'{index}.0.0.1'

    iface = node.get_interface(f"{node_name}-if1-p1").get_os_interface()
    config_script = f"""
        sudo apt-get update && sudo apt-get install -y net-tools;
        sudo ifconfig {iface} down;
        sudo ip link set dev {iface} address {mac};
        sudo ifconfig {iface} {ip};
        sudo ifconfig {iface} up;
        sudo ip route add default via {gw};
    """
    node.execute(config_script)

print('Done, move to the next step')
# Out:
# Changing the mac addresses of all nodes, master and client to match with the controller program
# Hit:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:2 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 Packages [8628 kB]
# Get:7 http://security.ubuntu.com/ubuntu focal-security/main Translation-en [518 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/universe Translation-en [221 kB]
# Get:10 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe Translation-en [5124 kB]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:12 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:13 http://security.ubuntu.com/ubuntu focal-security/multiverse Translation-en [6448 B]
# Get:14 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 c-n-f Metadata [265 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [144 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse Translation-en [104 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 c-n-f Metadata [9136 B]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3955 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main Translation-en [600 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe Translation-en [303 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse Translation-en [8316 B]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [45.7 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main Translation-en [16.3 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 c-n-f Metadata [1420 B]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [25.0 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe Translation-en [16.3 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 c-n-f Metadata [880 B]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/multiverse amd64 c-n-f Metadata [116 B]
# Fetched 26.4 MB in 4s (7377 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 192 kB of archives.
# After this operation, 856 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1.3 [192 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# Fetched 192 kB in 1s (200 kB/s)
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package net-tools.
# (Reading database ... 64241 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1.3_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Hit:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 Packages [8628 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe Translation-en [5124 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 c-n-f Metadata [265 kB]
# Get:8 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [144 kB]
# Get:9 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse Translation-en [104 kB]
# Get:10 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 c-n-f Metadata [9136 B]
# Get:11 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3955 kB]
# Get:12 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main Translation-en [600 kB]
# Get:13 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe Translation-en [303 kB]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse Translation-en [8316 B]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [45.7 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main Translation-en [16.3 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 c-n-f Metadata [1420 B]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [25.0 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe Translation-en [16.3 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 c-n-f Metadata [880 B]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/multiverse amd64 c-n-f Metadata [116 B]
# Get:27 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Get:28 http://security.ubuntu.com/ubuntu focal-security/main Translation-en [518 kB]
# Get:29 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:30 http://security.ubuntu.com/ubuntu focal-security/universe Translation-en [221 kB]
# Get:31 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:32 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:33 http://security.ubuntu.com/ubuntu focal-security/multiverse Translation-en [6448 B]
# Get:34 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Fetched 26.4 MB in 3s (8595 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 192 kB of archives.
# After this operation, 856 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1.3 [192 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 192 kB in 0s (416 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 64241 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1.3_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Hit:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:3 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu focal-security/main Translation-en [518 kB]
# Get:6 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:7 http://security.ubuntu.com/ubuntu focal-security/universe Translation-en [221 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/multiverse Translation-en [6448 B]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Get:12 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:13 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 Packages [8628 kB]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe Translation-en [5124 kB]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 c-n-f Metadata [265 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [144 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse Translation-en [104 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 c-n-f Metadata [9136 B]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3955 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main Translation-en [600 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe Translation-en [303 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse Translation-en [8316 B]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [45.7 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main Translation-en [16.3 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 c-n-f Metadata [1420 B]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [25.0 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe Translation-en [16.3 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 c-n-f Metadata [880 B]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/multiverse amd64 c-n-f Metadata [116 B]
# Fetched 26.4 MB in 3s (8803 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 192 kB of archives.
# After this operation, 856 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1.3 [192 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 192 kB in 1s (260 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 64241 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1.3_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Hit:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 Packages [8628 kB]
# Get:7 http://security.ubuntu.com/ubuntu focal-security/main Translation-en [518 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/universe Translation-en [221 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:12 http://security.ubuntu.com/ubuntu focal-security/multiverse Translation-en [6448 B]
# Get:13 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe Translation-en [5124 kB]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 c-n-f Metadata [265 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [144 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse Translation-en [104 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 c-n-f Metadata [9136 B]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3955 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main Translation-en [600 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe Translation-en [303 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse Translation-en [8316 B]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [45.7 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main Translation-en [16.3 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 c-n-f Metadata [1420 B]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [25.0 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe Translation-en [16.3 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 c-n-f Metadata [880 B]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/multiverse amd64 c-n-f Metadata [116 B]
# Fetched 26.4 MB in 4s (7344 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 192 kB of archives.
# After this operation, 856 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1.3 [192 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 192 kB in 0s (398 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 64241 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1.3_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Get:2 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Hit:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:6 http://security.ubuntu.com/ubuntu focal-security/main Translation-en [518 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 Packages [8628 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/universe Translation-en [221 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:12 http://security.ubuntu.com/ubuntu focal-security/multiverse Translation-en [6448 B]
# Get:13 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe Translation-en [5124 kB]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 c-n-f Metadata [265 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [144 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse Translation-en [104 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 c-n-f Metadata [9136 B]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3955 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main Translation-en [600 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe Translation-en [303 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse Translation-en [8316 B]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [45.7 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main Translation-en [16.3 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 c-n-f Metadata [1420 B]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [25.0 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe Translation-en [16.3 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 c-n-f Metadata [880 B]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/multiverse amd64 c-n-f Metadata [116 B]
# Fetched 26.4 MB in 4s (7049 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 192 kB of archives.
# After this operation, 856 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1.3 [192 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 192 kB in 0s (412 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 64241 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1.3_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Hit:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:3 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 Packages [8628 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe Translation-en [5124 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 c-n-f Metadata [265 kB]
# Get:8 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [144 kB]
# Get:9 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse Translation-en [104 kB]
# Get:10 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 c-n-f Metadata [9136 B]
# Get:11 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3955 kB]
# Get:12 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main Translation-en [600 kB]
# Get:13 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe Translation-en [303 kB]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse Translation-en [8316 B]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:19 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Get:20 http://security.ubuntu.com/ubuntu focal-security/main Translation-en [518 kB]
# Get:21 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:22 http://security.ubuntu.com/ubuntu focal-security/universe Translation-en [221 kB]
# Get:23 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:24 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:25 http://security.ubuntu.com/ubuntu focal-security/multiverse Translation-en [6448 B]
# Get:26 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [45.7 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main Translation-en [16.3 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 c-n-f Metadata [1420 B]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [25.0 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe Translation-en [16.3 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 c-n-f Metadata [880 B]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/multiverse amd64 c-n-f Metadata [116 B]
# Fetched 26.4 MB in 3s (9492 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 192 kB of archives.
# After this operation, 856 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1.3 [192 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 192 kB in 0s (2010 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 64241 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1.3_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Hit:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:2 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 Packages [8628 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe Translation-en [5124 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security/main Translation-en [518 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/universe Translation-en [221 kB]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:12 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:13 http://security.ubuntu.com/ubuntu focal-security/multiverse Translation-en [6448 B]
# Get:14 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 c-n-f Metadata [265 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [144 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse Translation-en [104 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 c-n-f Metadata [9136 B]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3955 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main Translation-en [600 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe Translation-en [303 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse Translation-en [8316 B]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [45.7 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main Translation-en [16.3 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 c-n-f Metadata [1420 B]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [25.0 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe Translation-en [16.3 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 c-n-f Metadata [880 B]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/multiverse amd64 c-n-f Metadata [116 B]
# Fetched 26.4 MB in 3s (7574 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 192 kB of archives.
# After this operation, 856 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1.3 [192 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 192 kB in 0s (603 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 64241 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1.3_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Hit:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:2 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 Packages [8628 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe Translation-en [5124 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security/main Translation-en [518 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:10 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 c-n-f Metadata [265 kB]
# Get:11 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [144 kB]
# Get:12 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse Translation-en [104 kB]
# Get:13 http://security.ubuntu.com/ubuntu focal-security/universe Translation-en [221 kB]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 c-n-f Metadata [9136 B]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3955 kB]
# Get:16 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:17 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:18 http://security.ubuntu.com/ubuntu focal-security/multiverse Translation-en [6448 B]
# Get:19 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main Translation-en [600 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe Translation-en [303 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse Translation-en [8316 B]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [45.7 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main Translation-en [16.3 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 c-n-f Metadata [1420 B]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [25.0 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe Translation-en [16.3 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 c-n-f Metadata [880 B]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/multiverse amd64 c-n-f Metadata [116 B]
# Fetched 26.4 MB in 4s (7384 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 192 kB of archives.
# After this operation, 856 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1.3 [192 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 192 kB in 1s (384 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 64241 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1.3_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Hit:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 Packages [8628 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe Translation-en [5124 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 c-n-f Metadata [265 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [144 kB]
# Get:8 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse Translation-en [104 kB]
# Get:9 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 c-n-f Metadata [9136 B]
# Get:10 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3955 kB]
# Get:11 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main Translation-en [600 kB]
# Get:12 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:13 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe Translation-en [303 kB]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse Translation-en [8316 B]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:18 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [45.7 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main Translation-en [16.3 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 c-n-f Metadata [1420 B]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [25.0 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe Translation-en [16.3 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 c-n-f Metadata [880 B]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/multiverse amd64 c-n-f Metadata [116 B]
# Get:27 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Get:28 http://security.ubuntu.com/ubuntu focal-security/main Translation-en [518 kB]
# Get:29 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:30 http://security.ubuntu.com/ubuntu focal-security/universe Translation-en [221 kB]
# Get:31 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:32 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:33 http://security.ubuntu.com/ubuntu focal-security/multiverse Translation-en [6448 B]
# Get:34 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Fetched 26.4 MB in 3s (9321 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 192 kB of archives.
# After this operation, 856 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1.3 [192 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 192 kB in 0s (422 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 64241 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1.3_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Hit:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:6 http://security.ubuntu.com/ubuntu focal-security/main Translation-en [518 kB]
# Get:7 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security/universe Translation-en [221 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/multiverse Translation-en [6448 B]
# Get:12 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Get:13 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 Packages [8628 kB]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe Translation-en [5124 kB]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 c-n-f Metadata [265 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [144 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse Translation-en [104 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 c-n-f Metadata [9136 B]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3955 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main Translation-en [600 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe Translation-en [303 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse Translation-en [8316 B]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [45.7 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main Translation-en [16.3 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 c-n-f Metadata [1420 B]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [25.0 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe Translation-en [16.3 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 c-n-f Metadata [880 B]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/multiverse amd64 c-n-f Metadata [116 B]
# Fetched 26.4 MB in 3s (7711 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 192 kB of archives.
# After this operation, 856 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1.3 [192 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 192 kB in 0s (412 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 64241 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1.3_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Hit:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Get:5 http://security.ubuntu.com/ubuntu focal-security/main Translation-en [518 kB]
# Get:6 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:7 http://security.ubuntu.com/ubuntu focal-security/universe Translation-en [221 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/multiverse Translation-en [6448 B]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Get:12 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:13 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 Packages [8628 kB]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe Translation-en [5124 kB]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 c-n-f Metadata [265 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [144 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse Translation-en [104 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 c-n-f Metadata [9136 B]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3955 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main Translation-en [600 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe Translation-en [303 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse Translation-en [8316 B]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [45.7 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main Translation-en [16.3 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 c-n-f Metadata [1420 B]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [25.0 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe Translation-en [16.3 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 c-n-f Metadata [880 B]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/multiverse amd64 c-n-f Metadata [116 B]
# Fetched 26.4 MB in 3s (8791 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 192 kB of archives.
# After this operation, 856 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1.3 [192 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 192 kB in 0s (416 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 64241 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1.3_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Hit:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:3 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Get:5 http://security.ubuntu.com/ubuntu focal-security/main Translation-en [518 kB]
# Get:6 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:7 http://security.ubuntu.com/ubuntu focal-security/universe Translation-en [221 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/multiverse Translation-en [6448 B]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Get:12 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:13 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 Packages [8628 kB]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe Translation-en [5124 kB]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 c-n-f Metadata [265 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [144 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse Translation-en [104 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 c-n-f Metadata [9136 B]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3955 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main Translation-en [600 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe Translation-en [303 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse Translation-en [8316 B]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [45.7 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main Translation-en [16.3 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 c-n-f Metadata [1420 B]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [25.0 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe Translation-en [16.3 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 c-n-f Metadata [880 B]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/multiverse amd64 c-n-f Metadata [116 B]
# Fetched 26.4 MB in 3s (8708 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 192 kB of archives.
# After this operation, 856 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1.3 [192 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 192 kB in 0s (416 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 64241 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1.3_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Done, move to the next step

# %%
print('Configuring IP addresses on the switch, to enable connectivity between hops')
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network

p4_node = slice.get_node('p4switch')

switch_ip_map = {
    'ms': '10.0.0.1',
    'cs': '21.0.0.1',
    'n1s': '11.0.0.1',
    'n2s': '12.0.0.1',
    'n3s': '13.0.0.1',
    'n4s': '14.0.0.1',
    'n5s': '15.0.0.1',
    'n6s': '16.0.0.1',
    'n7s': '17.0.0.1',
    'n8s': '18.0.0.1',
    'n9s': '19.0.0.1',
    'n10s': '20.0.0.1'
}

# Add IPs to p4switch's interfaces according to bridge mapping
for bridge, ip in switch_ip_map.items():
    iface = p4_node.get_interface(network_name=bridge)
    subnet = f'{ip[:-1]+"0"}/24'
    iface.ip_addr_add(addr=ip, subnet=IPv4Network(subnet))

# Boot script for switch: installs tools and brings up all interfaces
switch_script = """
    sudo apt-get update && sudo apt-get install -y net-tools;
    for iface in $(ls /sys/class/net | grep enp); do
        sudo ifconfig $iface up
    done;
"""
slice.get_node('p4switch').execute(switch_script)
print('Done, move to the next step')
# Out:
# Configuring IP addresses on the switch, to enable connectivity between hops
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Hit:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:3 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu focal-security/main Translation-en [518 kB]
# Get:6 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:7 http://security.ubuntu.com/ubuntu focal-security/universe Translation-en [221 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/multiverse Translation-en [6448 B]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Get:12 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:13 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 Packages [8628 kB]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe Translation-en [5124 kB]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 c-n-f Metadata [265 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [144 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse Translation-en [104 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 c-n-f Metadata [9136 B]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3955 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main Translation-en [600 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe Translation-en [303 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse Translation-en [8316 B]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [45.7 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main Translation-en [16.3 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 c-n-f Metadata [1420 B]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [25.0 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe Translation-en [16.3 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 c-n-f Metadata [880 B]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/multiverse amd64 c-n-f Metadata [116 B]
# Fetched 26.4 MB in 3s (8740 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 192 kB of archives.
# After this operation, 856 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1.3 [192 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 192 kB in 0s (420 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 64241 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1.3_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Done, move to the next step

# %%
print('Installing P4 software (p4c, bmv2) on the P4Switch node.')
p4_node = slice.get_node('p4switch')
switch_script = """
    git clone https://github.com/jafingerhut/p4-guide;
    git clone https://github.com/gareging/p4kube;
    cp p4kube/install-p4dev-v5.sh p4-guide/bin/install-p4dev-v5.sh
    sudo bash p4-guide/bin/install-p4dev-v5.sh; 
"""
slice.get_node('p4switch').execute(switch_script)
print('Done, move to the next step')
# Out:
# Installing P4 software (p4c, bmv2) on the P4Switch node.
# fatal: destination path 'p4-guide' already exists and is not an empty directory.
# fatal: destination path 'p4kube' already exists and is not an empty directory.
# Found distributor 'Ubuntu' release '20.04'.  Continuing with installation.
# Minimum recommended memory to run this script: 1920 MBytes
# Memory on this system from /proc/meminfo:      7945 MBytes -> enough
# Minimum free disk space to run this script:    2560 MBytes
# Free disk space on this system from df output:  7887 MBytes -> enough
# Found directory containing patches: /home/ubuntu/p4-guide/bin/patches
# Passed all sanity checks
# + set +x
# This script installs pre-compiled Debian packages of the P4_16 (and
# also P4_14) compiler, and the behavioral-model software packet
# forwarding program, that can behave as just about any legal P4
# program.
#
# It is regularly tested on freshly installed Ubuntu 20.04 systems,
# with all Ubuntu software updates as of the date of
# testing.  See this directory for log files recording the last
# date this script was tested on its supported operating systems:
#
#     https://github.com/jafingerhut/p4-guide/tree/master/bin/output
#
# As of 2021-Nov-14, the files installed by this script consume about 2
# GB of disk space.  Running the script downloads about 250 MBytes of
# data from the Internet.
#
# On a 2015 MacBook Pro with a decent speed Internet connection
# and an SSD drive, running Ubuntu Linux in a VirtualBox VM, it
# took about 3 minutes.
#
# ------------------------------------------------------------
# Time and disk space used before installation begins:
# Wed Nov 12 15:56:00 UTC 2025
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/vda1       9.6G  1.8G  7.8G  19% /
# Filesystem     1M-blocks  Used Available Use% Mounted on
# /dev/vda1          9741M 1838M     7887M  19% /
# + date
# + df -h .
# + df -BM .
# + lsb_release -a
# Distributor ID:	Ubuntu
# Description:	Ubuntu 20.04.6 LTS
# Release:	20.04
# Codename:	focal
# No LSB modules are available.
# No such command in PATH: python
# + python -V
# p4-guide/bin/install-p4dev-v5.sh: line 175: python: command not found
# + echo 'No such command in PATH: python'
# + python2 -V
# No such command in PATH: python2
# Python 3.8.10
# p4-guide/bin/install-p4dev-v5.sh: line 176: python2: command not found
# + echo 'No such command in PATH: python2'
# + python3 -V
# + pip -V
# p4-guide/bin/install-p4dev-v5.sh: line 178: pip: command not found
# No such command in PATH: pip
# No such command in PATH: pip2
# + echo 'No such command in PATH: pip'
# + pip2 -V
# p4-guide/bin/install-p4dev-v5.sh: line 179: pip2: command not found
# + echo 'No such command in PATH: pip2'
# + pip3 -V
# p4-guide/bin/install-p4dev-v5.sh: line 180: pip3: command not found
# No such command in PATH: pip3
# + echo 'No such command in PATH: pip3'
# + sudo apt-get install -qq -y --no-install-recommends --fix-missing curl git wget
# + export DEBIAN_FRONTEND=noninteractive
# + DEBIAN_FRONTEND=noninteractive
# + echo 'deb http://download.opensuse.org/repositories/home:/p4lang/xUbuntu_20.04/ /'
# + sudo tee /etc/apt/sources.list.d/home:p4lang.list
# deb http://download.opensuse.org/repositories/home:/p4lang/xUbuntu_20.04/ /
# + wget -qO - http://download.opensuse.org/repositories/home:/p4lang/xUbuntu_20.04/Release.key
# + sudo apt-key add -
# Warning: apt-key output should not be parsed (stdout is not a terminal)
# OK
# + set -e
# + REPO_FILE=/etc/apt/sources.list.d/home:p4lang.list
# + sudo bash -c 'cat > /etc/apt/sources.list.d/home:p4lang.list <<EOF
# deb [trusted=yes] http://download.opensuse.org/repositories/home:/p4lang/xUbuntu_20.04/ /
# EOF'
# + sudo apt-key del A4666B6753C0F7D1
# OK
# + sudo apt-get update -qq
# W: GPG error: http://download.opensuse.org/repositories/home:/p4lang/xUbuntu_20.04  InRelease: The following signatures couldn't be verified because the public key is not available: NO_PUBKEY A4666B6753C0F7D1
# + sudo apt-get install -qq -y --no-install-recommends --fix-missing iproute2 net-tools python3 python3-pip tcpdump unzip vim xterm p4lang-p4c p4lang-bmv2 p4lang-pi
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package m4.
# (Reading database ... 64290 files and directories currently installed.)
# Preparing to unpack .../000-m4_1.4.18-4_amd64.deb ...
# Unpacking m4 (1.4.18-4) ...
# Selecting previously unselected package flex.
# Preparing to unpack .../001-flex_2.6.4-6.2_amd64.deb ...
# Unpacking flex (2.6.4-6.2) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../002-autoconf_2.69-11.1_all.deb ...
# Unpacking autoconf (2.69-11.1) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../003-autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../004-automake_1%3a1.16.1-4ubuntu6_all.deb ...
# Unpacking automake (1:1.16.1-4ubuntu6) ...
# Selecting previously unselected package binfmt-support.
# Preparing to unpack .../005-binfmt-support_2.2.0-2_amd64.deb ...
# Unpacking binfmt-support (2.2.0-2) ...
# Selecting previously unselected package binutils-common:amd64.
# Preparing to unpack .../006-binutils-common_2.34-6ubuntu1.11_amd64.deb ...
# Unpacking binutils-common:amd64 (2.34-6ubuntu1.11) ...
# Selecting previously unselected package libbinutils:amd64.
# Preparing to unpack .../007-libbinutils_2.34-6ubuntu1.11_amd64.deb ...
# Unpacking libbinutils:amd64 (2.34-6ubuntu1.11) ...
# Selecting previously unselected package libctf-nobfd0:amd64.
# Preparing to unpack .../008-libctf-nobfd0_2.34-6ubuntu1.11_amd64.deb ...
# Unpacking libctf-nobfd0:amd64 (2.34-6ubuntu1.11) ...
# Selecting previously unselected package libctf0:amd64.
# Preparing to unpack .../009-libctf0_2.34-6ubuntu1.11_amd64.deb ...
# Unpacking libctf0:amd64 (2.34-6ubuntu1.11) ...
# Selecting previously unselected package binutils-x86-64-linux-gnu.
# Preparing to unpack .../010-binutils-x86-64-linux-gnu_2.34-6ubuntu1.11_amd64.deb ...
# Unpacking binutils-x86-64-linux-gnu (2.34-6ubuntu1.11) ...
# Selecting previously unselected package binutils.
# Preparing to unpack .../011-binutils_2.34-6ubuntu1.11_amd64.deb ...
# Unpacking binutils (2.34-6ubuntu1.11) ...
# Selecting previously unselected package libllvm10:amd64.
# Preparing to unpack .../012-libllvm10_1%3a10.0.0-4ubuntu1_amd64.deb ...
# Unpacking libllvm10:amd64 (1:10.0.0-4ubuntu1) ...
# Selecting previously unselected package libclang-cpp10.
# Preparing to unpack .../013-libclang-cpp10_1%3a10.0.0-4ubuntu1_amd64.deb ...
# Unpacking libclang-cpp10 (1:10.0.0-4ubuntu1) ...
# Selecting previously unselected package gcc-9-base:amd64.
# Preparing to unpack .../014-gcc-9-base_9.4.0-1ubuntu1~20.04.2_amd64.deb ...
# Unpacking gcc-9-base:amd64 (9.4.0-1ubuntu1~20.04.2) ...
# Selecting previously unselected package libgomp1:amd64.
# Preparing to unpack .../015-libgomp1_10.5.0-1ubuntu1~20.04_amd64.deb ...
# Unpacking libgomp1:amd64 (10.5.0-1ubuntu1~20.04) ...
# Selecting previously unselected package libitm1:amd64.
# Preparing to unpack .../016-libitm1_10.5.0-1ubuntu1~20.04_amd64.deb ...
# Unpacking libitm1:amd64 (10.5.0-1ubuntu1~20.04) ...
# Selecting previously unselected package libatomic1:amd64.
# Preparing to unpack .../017-libatomic1_10.5.0-1ubuntu1~20.04_amd64.deb ...
# Unpacking libatomic1:amd64 (10.5.0-1ubuntu1~20.04) ...
# Selecting previously unselected package libasan5:amd64.
# Preparing to unpack .../018-libasan5_9.4.0-1ubuntu1~20.04.2_amd64.deb ...
# Unpacking libasan5:amd64 (9.4.0-1ubuntu1~20.04.2) ...
# Selecting previously unselected package liblsan0:amd64.
# Preparing to unpack .../019-liblsan0_10.5.0-1ubuntu1~20.04_amd64.deb ...
# Unpacking liblsan0:amd64 (10.5.0-1ubuntu1~20.04) ...
# Selecting previously unselected package libtsan0:amd64.
# Preparing to unpack .../020-libtsan0_10.5.0-1ubuntu1~20.04_amd64.deb ...
# Unpacking libtsan0:amd64 (10.5.0-1ubuntu1~20.04) ...
# Selecting previously unselected package libubsan1:amd64.
# Preparing to unpack .../021-libubsan1_10.5.0-1ubuntu1~20.04_amd64.deb ...
# Unpacking libubsan1:amd64 (10.5.0-1ubuntu1~20.04) ...
# Selecting previously unselected package libquadmath0:amd64.
# Preparing to unpack .../022-libquadmath0_10.5.0-1ubuntu1~20.04_amd64.deb ...
# Unpacking libquadmath0:amd64 (10.5.0-1ubuntu1~20.04) ...
# Selecting previously unselected package libgcc-9-dev:amd64.
# Preparing to unpack .../023-libgcc-9-dev_9.4.0-1ubuntu1~20.04.2_amd64.deb ...
# Unpacking libgcc-9-dev:amd64 (9.4.0-1ubuntu1~20.04.2) ...
# Selecting previously unselected package libc-dev-bin.
# Preparing to unpack .../024-libc-dev-bin_2.31-0ubuntu9.18_amd64.deb ...
# Unpacking libc-dev-bin (2.31-0ubuntu9.18) ...
# Selecting previously unselected package linux-libc-dev:amd64.
# Preparing to unpack .../025-linux-libc-dev_5.4.0-216.236_amd64.deb ...
# Unpacking linux-libc-dev:amd64 (5.4.0-216.236) ...
# Selecting previously unselected package libcrypt-dev:amd64.
# Preparing to unpack .../026-libcrypt-dev_1%3a4.4.10-10ubuntu4_amd64.deb ...
# Unpacking libcrypt-dev:amd64 (1:4.4.10-10ubuntu4) ...
# Selecting previously unselected package libc6-dev:amd64.
# Preparing to unpack .../027-libc6-dev_2.31-0ubuntu9.18_amd64.deb ...
# Unpacking libc6-dev:amd64 (2.31-0ubuntu9.18) ...
# Selecting previously unselected package libstdc++-9-dev:amd64.
# Preparing to unpack .../028-libstdc++-9-dev_9.4.0-1ubuntu1~20.04.2_amd64.deb ...
# Unpacking libstdc++-9-dev:amd64 (9.4.0-1ubuntu1~20.04.2) ...
# Selecting previously unselected package libgc1c2:amd64.
# Preparing to unpack .../029-libgc1c2_1%3a7.6.4-0.4ubuntu1_amd64.deb ...
# Unpacking libgc1c2:amd64 (1:7.6.4-0.4ubuntu1) ...
# Selecting previously unselected package libobjc4:amd64.
# Preparing to unpack .../030-libobjc4_10.5.0-1ubuntu1~20.04_amd64.deb ...
# Unpacking libobjc4:amd64 (10.5.0-1ubuntu1~20.04) ...
# Selecting previously unselected package libobjc-9-dev:amd64.
# Preparing to unpack .../031-libobjc-9-dev_9.4.0-1ubuntu1~20.04.2_amd64.deb ...
# Unpacking libobjc-9-dev:amd64 (9.4.0-1ubuntu1~20.04.2) ...
# Selecting previously unselected package libc6-i386.
# Preparing to unpack .../032-libc6-i386_2.31-0ubuntu9.18_amd64.deb ...
# Unpacking libc6-i386 (2.31-0ubuntu9.18) ...
# Selecting previously unselected package lib32gcc-s1.
# Preparing to unpack .../033-lib32gcc-s1_10.5.0-1ubuntu1~20.04_amd64.deb ...
# Unpacking lib32gcc-s1 (10.5.0-1ubuntu1~20.04) ...
# Selecting previously unselected package lib32stdc++6.
# Preparing to unpack .../034-lib32stdc++6_10.5.0-1ubuntu1~20.04_amd64.deb ...
# Unpacking lib32stdc++6 (10.5.0-1ubuntu1~20.04) ...
# Selecting previously unselected package libclang-common-10-dev.
# Preparing to unpack .../035-libclang-common-10-dev_1%3a10.0.0-4ubuntu1_amd64.deb ...
# Unpacking libclang-common-10-dev (1:10.0.0-4ubuntu1) ...
# Selecting previously unselected package libclang1-10.
# Preparing to unpack .../036-libclang1-10_1%3a10.0.0-4ubuntu1_amd64.deb ...
# Unpacking libclang1-10 (1:10.0.0-4ubuntu1) ...
# Selecting previously unselected package clang-10.
# Preparing to unpack .../037-clang-10_1%3a10.0.0-4ubuntu1_amd64.deb ...
# Unpacking clang-10 (1:10.0.0-4ubuntu1) ...
# Selecting previously unselected package clang.
# Preparing to unpack .../038-clang_1%3a10.0-50~exp1_amd64.deb ...
# Unpacking clang (1:10.0-50~exp1) ...
# Selecting previously unselected package libisl22:amd64.
# Preparing to unpack .../039-libisl22_0.22.1-1_amd64.deb ...
# Unpacking libisl22:amd64 (0.22.1-1) ...
# Selecting previously unselected package libmpc3:amd64.
# Preparing to unpack .../040-libmpc3_1.1.0-1_amd64.deb ...
# Unpacking libmpc3:amd64 (1.1.0-1) ...
# Selecting previously unselected package cpp-9.
# Preparing to unpack .../041-cpp-9_9.4.0-1ubuntu1~20.04.2_amd64.deb ...
# Unpacking cpp-9 (9.4.0-1ubuntu1~20.04.2) ...
# Selecting previously unselected package cpp.
# Preparing to unpack .../042-cpp_4%3a9.3.0-1ubuntu2_amd64.deb ...
# Unpacking cpp (4:9.3.0-1ubuntu2) ...
# Selecting previously unselected package libllvm18:amd64.
# Preparing to unpack .../043-libllvm18_1%3a18.1.8-11~20.04.2_amd64.deb ...
# Unpacking libllvm18:amd64 (1:18.1.8-11~20.04.2) ...
# Selecting previously unselected package libclang-cpp18.
# Preparing to unpack .../044-libclang-cpp18_1%3a18.1.8-11~20.04.2_amd64.deb ...
# Unpacking libclang-cpp18 (1:18.1.8-11~20.04.2) ...
# Selecting previously unselected package libasan6:amd64.
# Preparing to unpack .../045-libasan6_10.5.0-1ubuntu1~20.04_amd64.deb ...
# Unpacking libasan6:amd64 (10.5.0-1ubuntu1~20.04) ...
# Selecting previously unselected package libgcc-10-dev:amd64.
# Preparing to unpack .../046-libgcc-10-dev_10.5.0-1ubuntu1~20.04_amd64.deb ...
# Unpacking libgcc-10-dev:amd64 (10.5.0-1ubuntu1~20.04) ...
# Selecting previously unselected package libstdc++-10-dev:amd64.
# Preparing to unpack .../047-libstdc++-10-dev_10.5.0-1ubuntu1~20.04_amd64.deb ...
# Unpacking libstdc++-10-dev:amd64 (10.5.0-1ubuntu1~20.04) ...
# Selecting previously unselected package libflang-18-dev.
# Preparing to unpack .../048-libflang-18-dev_1%3a18.1.8-11~20.04.2_amd64.deb ...
# Unpacking libflang-18-dev (1:18.1.8-11~20.04.2) ...
# Selecting previously unselected package flang-18.
# Preparing to unpack .../049-flang-18_1%3a18.1.8-11~20.04.2_amd64.deb ...
# Unpacking flang-18 (1:18.1.8-11~20.04.2) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../050-fonts-dejavu-core_2.37-1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fontconfig-config.
# Preparing to unpack .../051-fontconfig-config_2.13.1-2ubuntu3_all.deb ...
# Unpacking fontconfig-config (2.13.1-2ubuntu3) ...
# Selecting previously unselected package libcc1-0:amd64.
# Preparing to unpack .../052-libcc1-0_10.5.0-1ubuntu1~20.04_amd64.deb ...
# Unpacking libcc1-0:amd64 (10.5.0-1ubuntu1~20.04) ...
# Selecting previously unselected package gcc-9.
# Preparing to unpack .../053-gcc-9_9.4.0-1ubuntu1~20.04.2_amd64.deb ...
# Unpacking gcc-9 (9.4.0-1ubuntu1~20.04.2) ...
# Selecting previously unselected package gcc.
# Preparing to unpack .../054-gcc_4%3a9.3.0-1ubuntu2_amd64.deb ...
# Unpacking gcc (4:9.3.0-1ubuntu2) ...
# Selecting previously unselected package gcc-7-base:amd64.
# Preparing to unpack .../055-gcc-7-base_7.5.0-6ubuntu2_amd64.deb ...
# Unpacking gcc-7-base:amd64 (7.5.0-6ubuntu2) ...
# Selecting previously unselected package gcc-8-base:amd64.
# Preparing to unpack .../056-gcc-8-base_8.4.0-3ubuntu2_amd64.deb ...
# Unpacking gcc-8-base:amd64 (8.4.0-3ubuntu2) ...
# Selecting previously unselected package libnl-3-200:amd64.
# Preparing to unpack .../057-libnl-3-200_3.4.0-1ubuntu0.1_amd64.deb ...
# Unpacking libnl-3-200:amd64 (3.4.0-1ubuntu0.1) ...
# Selecting previously unselected package libnl-route-3-200:amd64.
# Preparing to unpack .../058-libnl-route-3-200_3.4.0-1ubuntu0.1_amd64.deb ...
# Unpacking libnl-route-3-200:amd64 (3.4.0-1ubuntu0.1) ...
# Selecting previously unselected package libibverbs1:amd64.
# Preparing to unpack .../059-libibverbs1_28.0-1ubuntu1_amd64.deb ...
# Unpacking libibverbs1:amd64 (28.0-1ubuntu1) ...
# Selecting previously unselected package ibverbs-providers:amd64.
# Preparing to unpack .../060-ibverbs-providers_28.0-1ubuntu1_amd64.deb ...
# Unpacking ibverbs-providers:amd64 (28.0-1ubuntu1) ...
# Selecting previously unselected package icu-devtools.
# Preparing to unpack .../061-icu-devtools_66.1-2ubuntu2.1_amd64.deb ...
# Unpacking icu-devtools (66.1-2ubuntu2.1) ...
# Selecting previously unselected package libasan4:amd64.
# Preparing to unpack .../062-libasan4_7.5.0-6ubuntu2_amd64.deb ...
# Unpacking libasan4:amd64 (7.5.0-6ubuntu2) ...
# Selecting previously unselected package libubsan0:amd64.
# Preparing to unpack .../063-libubsan0_7.5.0-6ubuntu2_amd64.deb ...
# Unpacking libubsan0:amd64 (7.5.0-6ubuntu2) ...
# Selecting previously unselected package libcilkrts5:amd64.
# Preparing to unpack .../064-libcilkrts5_7.5.0-6ubuntu2_amd64.deb ...
# Unpacking libcilkrts5:amd64 (7.5.0-6ubuntu2) ...
# Selecting previously unselected package libmpx2:amd64.
# Preparing to unpack .../065-libmpx2_8.4.0-3ubuntu2_amd64.deb ...
# Unpacking libmpx2:amd64 (8.4.0-3ubuntu2) ...
# Selecting previously unselected package libgcc-7-dev:amd64.
# Preparing to unpack .../066-libgcc-7-dev_7.5.0-6ubuntu2_amd64.deb ...
# Unpacking libgcc-7-dev:amd64 (7.5.0-6ubuntu2) ...
# Selecting previously unselected package libstdc++-7-dev:amd64.
# Preparing to unpack .../067-libstdc++-7-dev_7.5.0-6ubuntu2_amd64.deb ...
# Unpacking libstdc++-7-dev:amd64 (7.5.0-6ubuntu2) ...
# Selecting previously unselected package libboost1.71-dev:amd64.
# Preparing to unpack .../068-libboost1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-dev:amd64.
# Preparing to unpack .../069-libboost-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost1.71-tools-dev.
# Preparing to unpack .../070-libboost1.71-tools-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost1.71-tools-dev (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-tools-dev.
# Preparing to unpack .../071-libboost-tools-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-tools-dev (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-atomic1.71.0:amd64.
# Preparing to unpack .../072-libboost-atomic1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-atomic1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-atomic1.71-dev:amd64.
# Preparing to unpack .../073-libboost-atomic1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-atomic1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-atomic-dev:amd64.
# Preparing to unpack .../074-libboost-atomic-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-atomic-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-chrono1.71.0:amd64.
# Preparing to unpack .../075-libboost-chrono1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-chrono1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-chrono1.71-dev:amd64.
# Preparing to unpack .../076-libboost-chrono1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-chrono1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-chrono-dev:amd64.
# Preparing to unpack .../077-libboost-chrono-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-chrono-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-container1.71.0:amd64.
# Preparing to unpack .../078-libboost-container1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-container1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-container1.71-dev:amd64.
# Preparing to unpack .../079-libboost-container1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-container1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-container-dev:amd64.
# Preparing to unpack .../080-libboost-container-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-container-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-date-time1.71.0:amd64.
# Preparing to unpack .../081-libboost-date-time1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-date-time1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-serialization1.71.0:amd64.
# Preparing to unpack .../082-libboost-serialization1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-serialization1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-serialization1.71-dev:amd64.
# Preparing to unpack .../083-libboost-serialization1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-serialization1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-date-time1.71-dev:amd64.
# Preparing to unpack .../084-libboost-date-time1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-date-time1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-system1.71.0:amd64.
# Preparing to unpack .../085-libboost-system1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-system1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-system1.71-dev:amd64.
# Preparing to unpack .../086-libboost-system1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-system1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-thread1.71.0:amd64.
# Preparing to unpack .../087-libboost-thread1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-thread1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-thread1.71-dev:amd64.
# Preparing to unpack .../088-libboost-thread1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-thread1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-context1.71.0:amd64.
# Preparing to unpack .../089-libboost-context1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-context1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-context1.71-dev:amd64.
# Preparing to unpack .../090-libboost-context1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-context1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-context-dev:amd64.
# Preparing to unpack .../091-libboost-context-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-context-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-coroutine1.71.0:amd64.
# Preparing to unpack .../092-libboost-coroutine1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-coroutine1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-coroutine1.71-dev:amd64.
# Preparing to unpack .../093-libboost-coroutine1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-coroutine1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-coroutine-dev:amd64.
# Preparing to unpack .../094-libboost-coroutine-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-coroutine-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-date-time-dev:amd64.
# Preparing to unpack .../095-libboost-date-time-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-date-time-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-exception1.71-dev:amd64.
# Preparing to unpack .../096-libboost-exception1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-exception1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-exception-dev:amd64.
# Preparing to unpack .../097-libboost-exception-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-exception-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-filesystem1.71.0:amd64.
# Preparing to unpack .../098-libboost-filesystem1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-filesystem1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-filesystem1.71-dev:amd64.
# Preparing to unpack .../099-libboost-filesystem1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-filesystem1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-fiber1.71.0:amd64.
# Preparing to unpack .../100-libboost-fiber1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-fiber1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-fiber1.71-dev:amd64.
# Preparing to unpack .../101-libboost-fiber1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-fiber1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-fiber-dev:amd64.
# Preparing to unpack .../102-libboost-fiber-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-fiber-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-filesystem-dev:amd64.
# Preparing to unpack .../103-libboost-filesystem-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-filesystem-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-regex1.71.0:amd64.
# Preparing to unpack .../104-libboost-regex1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-regex1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-graph1.71.0:amd64.
# Preparing to unpack .../105-libboost-graph1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-graph1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libicu-dev:amd64.
# Preparing to unpack .../106-libicu-dev_66.1-2ubuntu2.1_amd64.deb ...
# Unpacking libicu-dev:amd64 (66.1-2ubuntu2.1) ...
# Selecting previously unselected package libboost-regex1.71-dev:amd64.
# Preparing to unpack .../107-libboost-regex1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-regex1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-test1.71.0:amd64.
# Preparing to unpack .../108-libboost-test1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-test1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-test1.71-dev:amd64.
# Preparing to unpack .../109-libboost-test1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-test1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-graph1.71-dev:amd64.
# Preparing to unpack .../110-libboost-graph1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-graph1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-graph-dev:amd64.
# Preparing to unpack .../111-libboost-graph-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-graph-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libevent-core-2.1-7:amd64.
# Preparing to unpack .../112-libevent-core-2.1-7_2.1.11-stable-1_amd64.deb ...
# Unpacking libevent-core-2.1-7:amd64 (2.1.11-stable-1) ...
# Selecting previously unselected package libevent-pthreads-2.1-7:amd64.
# Preparing to unpack .../113-libevent-pthreads-2.1-7_2.1.11-stable-1_amd64.deb ...
# Unpacking libevent-pthreads-2.1-7:amd64 (2.1.11-stable-1) ...
# Selecting previously unselected package libpsm-infinipath1.
# Preparing to unpack .../114-libpsm-infinipath1_3.3+20.604758e7-6_amd64.deb ...
# Unpacking libpsm-infinipath1 (3.3+20.604758e7-6) ...
# Selecting previously unselected package libpsm2-2.
# Preparing to unpack .../115-libpsm2-2_11.2.86-1_amd64.deb ...
# Unpacking libpsm2-2 (11.2.86-1) ...
# Selecting previously unselected package librdmacm1:amd64.
# Preparing to unpack .../116-librdmacm1_28.0-1ubuntu1_amd64.deb ...
# Unpacking librdmacm1:amd64 (28.0-1ubuntu1) ...
# Selecting previously unselected package libfabric1.
# Preparing to unpack .../117-libfabric1_1.6.2-3ubuntu0.1_amd64.deb ...
# Unpacking libfabric1 (1.6.2-3ubuntu0.1) ...
# Selecting previously unselected package libhwloc15:amd64.
# Preparing to unpack .../118-libhwloc15_2.1.0+dfsg-4_amd64.deb ...
# Unpacking libhwloc15:amd64 (2.1.0+dfsg-4) ...
# Selecting previously unselected package libpciaccess0:amd64.
# Preparing to unpack .../119-libpciaccess0_0.16-0ubuntu1_amd64.deb ...
# Unpacking libpciaccess0:amd64 (0.16-0ubuntu1) ...
# Selecting previously unselected package libxnvctrl0:amd64.
# Preparing to unpack .../120-libxnvctrl0_470.57.01-0ubuntu0.20.04.3_amd64.deb ...
# Unpacking libxnvctrl0:amd64 (470.57.01-0ubuntu0.20.04.3) ...
# Selecting previously unselected package ocl-icd-libopencl1:amd64.
# Preparing to unpack .../121-ocl-icd-libopencl1_2.2.11-1ubuntu1_amd64.deb ...
# Unpacking ocl-icd-libopencl1:amd64 (2.2.11-1ubuntu1) ...
# Selecting previously unselected package libhwloc-plugins:amd64.
# Preparing to unpack .../122-libhwloc-plugins_2.1.0+dfsg-4_amd64.deb ...
# Unpacking libhwloc-plugins:amd64 (2.1.0+dfsg-4) ...
# Selecting previously unselected package libpmix2:amd64.
# Preparing to unpack .../123-libpmix2_3.1.5-1_amd64.deb ...
# Unpacking libpmix2:amd64 (3.1.5-1) ...
# Selecting previously unselected package libopenmpi3:amd64.
# Preparing to unpack .../124-libopenmpi3_4.0.3-0ubuntu1_amd64.deb ...
# Unpacking libopenmpi3:amd64 (4.0.3-0ubuntu1) ...
# Selecting previously unselected package libboost-mpi1.71.0.
# Preparing to unpack .../125-libboost-mpi1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-mpi1.71.0 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-graph-parallel1.71.0.
# Preparing to unpack .../126-libboost-graph-parallel1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-graph-parallel1.71.0 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-graph-parallel1.71-dev.
# Preparing to unpack .../127-libboost-graph-parallel1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-graph-parallel1.71-dev (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-graph-parallel-dev.
# Preparing to unpack .../128-libboost-graph-parallel-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-graph-parallel-dev (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-iostreams1.71.0:amd64.
# Preparing to unpack .../129-libboost-iostreams1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-iostreams1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-iostreams1.71-dev:amd64.
# Preparing to unpack .../130-libboost-iostreams1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-iostreams1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-iostreams-dev:amd64.
# Preparing to unpack .../131-libboost-iostreams-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-iostreams-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-locale1.71.0:amd64.
# Preparing to unpack .../132-libboost-locale1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-locale1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-locale1.71-dev:amd64.
# Preparing to unpack .../133-libboost-locale1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-locale1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-locale-dev:amd64.
# Preparing to unpack .../134-libboost-locale-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-locale-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-log1.71.0.
# Preparing to unpack .../135-libboost-log1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-log1.71.0 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-log1.71-dev.
# Preparing to unpack .../136-libboost-log1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-log1.71-dev (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-log-dev.
# Preparing to unpack .../137-libboost-log-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-log-dev (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-math1.71.0:amd64.
# Preparing to unpack .../138-libboost-math1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-math1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-math1.71-dev:amd64.
# Preparing to unpack .../139-libboost-math1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-math1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-math-dev:amd64.
# Preparing to unpack .../140-libboost-math-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-math-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package openmpi-common.
# Preparing to unpack .../141-openmpi-common_4.0.3-0ubuntu1_all.deb ...
# Unpacking openmpi-common (4.0.3-0ubuntu1) ...
# Selecting previously unselected package libnl-3-dev:amd64.
# Preparing to unpack .../142-libnl-3-dev_3.4.0-1ubuntu0.1_amd64.deb ...
# Unpacking libnl-3-dev:amd64 (3.4.0-1ubuntu0.1) ...
# Selecting previously unselected package libnl-route-3-dev:amd64.
# Preparing to unpack .../143-libnl-route-3-dev_3.4.0-1ubuntu0.1_amd64.deb ...
# Unpacking libnl-route-3-dev:amd64 (3.4.0-1ubuntu0.1) ...
# Selecting previously unselected package libibverbs-dev:amd64.
# Preparing to unpack .../144-libibverbs-dev_28.0-1ubuntu1_amd64.deb ...
# Unpacking libibverbs-dev:amd64 (28.0-1ubuntu1) ...
# Selecting previously unselected package libnuma-dev:amd64.
# Preparing to unpack .../145-libnuma-dev_2.0.12-1_amd64.deb ...
# Unpacking libnuma-dev:amd64 (2.0.12-1) ...
# Selecting previously unselected package libltdl-dev:amd64.
# Preparing to unpack .../146-libltdl-dev_2.4.6-14_amd64.deb ...
# Unpacking libltdl-dev:amd64 (2.4.6-14) ...
# Selecting previously unselected package libhwloc-dev:amd64.
# Preparing to unpack .../147-libhwloc-dev_2.1.0+dfsg-4_amd64.deb ...
# Unpacking libhwloc-dev:amd64 (2.1.0+dfsg-4) ...
# Selecting previously unselected package libevent-extra-2.1-7:amd64.
# Preparing to unpack .../148-libevent-extra-2.1-7_2.1.11-stable-1_amd64.deb ...
# Unpacking libevent-extra-2.1-7:amd64 (2.1.11-stable-1) ...
# Selecting previously unselected package libevent-openssl-2.1-7:amd64.
# Preparing to unpack .../149-libevent-openssl-2.1-7_2.1.11-stable-1_amd64.deb ...
# Unpacking libevent-openssl-2.1-7:amd64 (2.1.11-stable-1) ...
# Selecting previously unselected package libevent-dev.
# Preparing to unpack .../150-libevent-dev_2.1.11-stable-1_amd64.deb ...
# Unpacking libevent-dev (2.1.11-stable-1) ...
# Selecting previously unselected package openmpi-bin.
# Preparing to unpack .../151-openmpi-bin_4.0.3-0ubuntu1_amd64.deb ...
# Unpacking openmpi-bin (4.0.3-0ubuntu1) ...
# Selecting previously unselected package libopenmpi-dev:amd64.
# Preparing to unpack .../152-libopenmpi-dev_4.0.3-0ubuntu1_amd64.deb ...
# Unpacking libopenmpi-dev:amd64 (4.0.3-0ubuntu1) ...
# Selecting previously unselected package mpi-default-dev.
# Preparing to unpack .../153-mpi-default-dev_1.13_amd64.deb ...
# Unpacking mpi-default-dev (1.13) ...
# Selecting previously unselected package libboost-mpi1.71-dev.
# Preparing to unpack .../154-libboost-mpi1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-mpi1.71-dev (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-mpi-dev.
# Preparing to unpack .../155-libboost-mpi-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-mpi-dev (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-python1.71.0.
# Preparing to unpack .../156-libboost-python1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-python1.71.0 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package mpi-default-bin.
# Preparing to unpack .../157-mpi-default-bin_1.13_amd64.deb ...
# Unpacking mpi-default-bin (1.13) ...
# Selecting previously unselected package libboost-mpi-python1.71.0.
# Preparing to unpack .../158-libboost-mpi-python1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-mpi-python1.71.0 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-mpi-python1.71-dev.
# Preparing to unpack .../159-libboost-mpi-python1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-mpi-python1.71-dev (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-mpi-python-dev.
# Preparing to unpack .../160-libboost-mpi-python-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-mpi-python-dev (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-numpy1.71.0.
# Preparing to unpack .../161-libboost-numpy1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-numpy1.71.0 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-numpy1.71-dev.
# Preparing to unpack .../162-libboost-numpy1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-numpy1.71-dev (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-numpy-dev.
# Preparing to unpack .../163-libboost-numpy-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-numpy-dev (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-program-options1.71.0:amd64.
# Preparing to unpack .../164-libboost-program-options1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-program-options1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-program-options1.71-dev:amd64.
# Preparing to unpack .../165-libboost-program-options1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-program-options1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-program-options-dev:amd64.
# Preparing to unpack .../166-libboost-program-options-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-program-options-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libexpat1-dev:amd64.
# Preparing to unpack .../167-libexpat1-dev_2.2.9-1ubuntu0.8_amd64.deb ...
# Unpacking libexpat1-dev:amd64 (2.2.9-1ubuntu0.8) ...
# Selecting previously unselected package libpython3.8-dev:amd64.
# Preparing to unpack .../168-libpython3.8-dev_3.8.10-0ubuntu1~20.04.18_amd64.deb ...
# Unpacking libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.18) ...
# Selecting previously unselected package libpython3-dev:amd64.
# Preparing to unpack .../169-libpython3-dev_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking libpython3-dev:amd64 (3.8.2-0ubuntu2) ...
# Selecting previously unselected package zlib1g-dev:amd64.
# Preparing to unpack .../170-zlib1g-dev_1%3a1.2.11.dfsg-2ubuntu1.5_amd64.deb ...
# Unpacking zlib1g-dev:amd64 (1:1.2.11.dfsg-2ubuntu1.5) ...
# Selecting previously unselected package python3.8-dev.
# Preparing to unpack .../171-python3.8-dev_3.8.10-0ubuntu1~20.04.18_amd64.deb ...
# Unpacking python3.8-dev (3.8.10-0ubuntu1~20.04.18) ...
# Selecting previously unselected package python3-dev.
# Preparing to unpack .../172-python3-dev_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking python3-dev (3.8.2-0ubuntu2) ...
# Selecting previously unselected package libboost-python1.71-dev.
# Preparing to unpack .../173-libboost-python1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-python1.71-dev (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-python-dev.
# Preparing to unpack .../174-libboost-python-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-python-dev (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-random1.71.0:amd64.
# Preparing to unpack .../175-libboost-random1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-random1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-random1.71-dev:amd64.
# Preparing to unpack .../176-libboost-random1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-random1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-random-dev:amd64.
# Preparing to unpack .../177-libboost-random-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-random-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-regex-dev:amd64.
# Preparing to unpack .../178-libboost-regex-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-regex-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-serialization-dev:amd64.
# Preparing to unpack .../179-libboost-serialization-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-serialization-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-stacktrace1.71.0:amd64.
# Preparing to unpack .../180-libboost-stacktrace1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-stacktrace1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-stacktrace1.71-dev:amd64.
# Preparing to unpack .../181-libboost-stacktrace1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-stacktrace1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-stacktrace-dev:amd64.
# Preparing to unpack .../182-libboost-stacktrace-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-stacktrace-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-system-dev:amd64.
# Preparing to unpack .../183-libboost-system-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-system-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-test-dev:amd64.
# Preparing to unpack .../184-libboost-test-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-test-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-thread-dev:amd64.
# Preparing to unpack .../185-libboost-thread-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-thread-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-timer1.71.0:amd64.
# Preparing to unpack .../186-libboost-timer1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-timer1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-timer1.71-dev:amd64.
# Preparing to unpack .../187-libboost-timer1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-timer1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-timer-dev:amd64.
# Preparing to unpack .../188-libboost-timer-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-timer-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-type-erasure1.71.0:amd64.
# Preparing to unpack .../189-libboost-type-erasure1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-type-erasure1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-type-erasure1.71-dev:amd64.
# Preparing to unpack .../190-libboost-type-erasure1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-type-erasure1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-type-erasure-dev:amd64.
# Preparing to unpack .../191-libboost-type-erasure-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-type-erasure-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-wave1.71.0:amd64.
# Preparing to unpack .../192-libboost-wave1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-wave1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-wave1.71-dev:amd64.
# Preparing to unpack .../193-libboost-wave1.71-dev_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-wave1.71-dev:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-wave-dev:amd64.
# Preparing to unpack .../194-libboost-wave-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-wave-dev:amd64 (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libboost-all-dev.
# Preparing to unpack .../195-libboost-all-dev_1.71.0.0ubuntu2_amd64.deb ...
# Unpacking libboost-all-dev (1.71.0.0ubuntu2) ...
# Selecting previously unselected package libbpf0:amd64.
# Preparing to unpack .../196-libbpf0_1%3a0.5.0-1_amd64.deb ...
# Unpacking libbpf0:amd64 (1:0.5.0-1) ...
# Selecting previously unselected package libelf-dev:amd64.
# Preparing to unpack .../197-libelf-dev_0.176-1.1ubuntu0.1_amd64.deb ...
# Unpacking libelf-dev:amd64 (0.176-1.1ubuntu0.1) ...
# Selecting previously unselected package libbpf-dev:amd64.
# Preparing to unpack .../198-libbpf-dev_1%3a0.5.0-1_amd64.deb ...
# Unpacking libbpf-dev:amd64 (1:0.5.0-1) ...
# Selecting previously unselected package libdouble-conversion3:amd64.
# Preparing to unpack .../199-libdouble-conversion3_3.1.5-4ubuntu1_amd64.deb ...
# Unpacking libdouble-conversion3:amd64 (3.1.5-4ubuntu1) ...
# Selecting previously unselected package libdpkg-perl.
# Preparing to unpack .../200-libdpkg-perl_1.19.7ubuntu3.2_all.deb ...
# Unpacking libdpkg-perl (1.19.7ubuntu3.2) ...
# Selecting previously unselected package libfl-dev:amd64.
# Preparing to unpack .../201-libfl-dev_2.6.4-6.2_amd64.deb ...
# Unpacking libfl-dev:amd64 (2.6.4-6.2) ...
# Selecting previously unselected package libfontconfig1:amd64.
# Preparing to unpack .../202-libfontconfig1_2.13.1-2ubuntu3_amd64.deb ...
# Unpacking libfontconfig1:amd64 (2.13.1-2ubuntu3) ...
# Selecting previously unselected package libgc-dev:amd64.
# Preparing to unpack .../203-libgc-dev_1%3a7.6.4-0.4ubuntu1_amd64.deb ...
# Unpacking libgc-dev:amd64 (1:7.6.4-0.4ubuntu1) ...
# Selecting previously unselected package libgmpxx4ldbl:amd64.
# Preparing to unpack .../204-libgmpxx4ldbl_2%3a6.2.0+dfsg-4ubuntu0.1_amd64.deb ...
# Unpacking libgmpxx4ldbl:amd64 (2:6.2.0+dfsg-4ubuntu0.1) ...
# Selecting previously unselected package libgmp-dev:amd64.
# Preparing to unpack .../205-libgmp-dev_2%3a6.2.0+dfsg-4ubuntu0.1_amd64.deb ...
# Unpacking libgmp-dev:amd64 (2:6.2.0+dfsg-4ubuntu0.1) ...
# Selecting previously unselected package libc-ares2:amd64.
# Preparing to unpack .../206-libc-ares2_1.15.0-1ubuntu0.5_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.15.0-1ubuntu0.5) ...
# Selecting previously unselected package libgrpc6:amd64.
# Preparing to unpack .../207-libgrpc6_1.16.1-1ubuntu5_amd64.deb ...
# Unpacking libgrpc6:amd64 (1.16.1-1ubuntu5) ...
# Selecting previously unselected package libprotobuf17:amd64.
# Preparing to unpack .../208-libprotobuf17_3.6.1.3-2ubuntu5.2_amd64.deb ...
# Unpacking libprotobuf17:amd64 (3.6.1.3-2ubuntu5.2) ...
# Selecting previously unselected package libgrpc++1:amd64.
# Preparing to unpack .../209-libgrpc++1_1.16.1-1ubuntu5_amd64.deb ...
# Unpacking libgrpc++1:amd64 (1.16.1-1ubuntu5) ...
# Selecting previously unselected package libgrpc-dev:amd64.
# Preparing to unpack .../210-libgrpc-dev_1.16.1-1ubuntu5_amd64.deb ...
# Unpacking libgrpc-dev:amd64 (1.16.1-1ubuntu5) ...
# Selecting previously unselected package libgrpc++-dev:amd64.
# Preparing to unpack .../211-libgrpc++-dev_1.16.1-1ubuntu5_amd64.deb ...
# Unpacking libgrpc++-dev:amd64 (1.16.1-1ubuntu5) ...
# Selecting previously unselected package x11-common.
# Preparing to unpack .../212-x11-common_1%3a7.7+19ubuntu14_all.deb ...
# dpkg-query: no packages found matching nux-tools
# Unpacking x11-common (1:7.7+19ubuntu14) ...
# Selecting previously unselected package libice6:amd64.
# Preparing to unpack .../213-libice6_2%3a1.0.10-0ubuntu1_amd64.deb ...
# Unpacking libice6:amd64 (2:1.0.10-0ubuntu1) ...
# Selecting previously unselected package libnanomsg5.
# Preparing to unpack .../214-libnanomsg5_1.1.5+dfsg-1_amd64.deb ...
# Unpacking libnanomsg5 (1.1.5+dfsg-1) ...
# Selecting previously unselected package libpcap0.8-dev:amd64.
# Preparing to unpack .../215-libpcap0.8-dev_1.9.1-3ubuntu1.20.04.1_amd64.deb ...
# Unpacking libpcap0.8-dev:amd64 (1.9.1-3ubuntu1.20.04.1) ...
# Selecting previously unselected package libpcap-dev:amd64.
# Preparing to unpack .../216-libpcap-dev_1.9.1-3ubuntu1.20.04.1_amd64.deb ...
# Unpacking libpcap-dev:amd64 (1.9.1-3ubuntu1.20.04.1) ...
# Selecting previously unselected package libpcre2-16-0:amd64.
# Preparing to unpack .../217-libpcre2-16-0_10.34-7ubuntu0.1_amd64.deb ...
# Unpacking libpcre2-16-0:amd64 (10.34-7ubuntu0.1) ...
# Selecting previously unselected package libprotobuf-lite17:amd64.
# Preparing to unpack .../218-libprotobuf-lite17_3.6.1.3-2ubuntu5.2_amd64.deb ...
# Unpacking libprotobuf-lite17:amd64 (3.6.1.3-2ubuntu5.2) ...
# Selecting previously unselected package libprotoc17:amd64.
# Preparing to unpack .../219-libprotoc17_3.6.1.3-2ubuntu5.2_amd64.deb ...
# Unpacking libprotoc17:amd64 (3.6.1.3-2ubuntu5.2) ...
# Selecting previously unselected package libqt5core5a:amd64.
# Preparing to unpack .../220-libqt5core5a_5.12.8+dfsg-0ubuntu2.1_amd64.deb ...
# Unpacking libqt5core5a:amd64 (5.12.8+dfsg-0ubuntu2.1) ...
# Selecting previously unselected package libqt5dbus5:amd64.
# Preparing to unpack .../221-libqt5dbus5_5.12.8+dfsg-0ubuntu2.1_amd64.deb ...
# Unpacking libqt5dbus5:amd64 (5.12.8+dfsg-0ubuntu2.1) ...
# Selecting previously unselected package libqt5network5:amd64.
# Preparing to unpack .../222-libqt5network5_5.12.8+dfsg-0ubuntu2.1_amd64.deb ...
# Unpacking libqt5network5:amd64 (5.12.8+dfsg-0ubuntu2.1) ...
# Selecting previously unselected package libsm6:amd64.
# Preparing to unpack .../223-libsm6_2%3a1.2.3-1_amd64.deb ...
# Unpacking libsm6:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package libssl-dev:amd64.
# Preparing to unpack .../224-libssl-dev_1.1.1f-1ubuntu2.24_amd64.deb ...
# Unpacking libssl-dev:amd64 (1.1.1f-1ubuntu2.24) ...
# Selecting previously unselected package libthrift-0.13.0.
# Preparing to unpack .../225-libthrift-0.13.0_0.13.0-2build2_amd64.deb ...
# Unpacking libthrift-0.13.0 (0.13.0-2build2) ...
# Selecting previously unselected package pkg-config.
# Preparing to unpack .../226-pkg-config_0.29.1-0ubuntu4_amd64.deb ...
# Unpacking pkg-config (0.29.1-0ubuntu4) ...
# ...
# drwxr-sr-x 5 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_cython
# -rw-r--r-- 1 root staff      577 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_cython/__init__.py
# drwxr-sr-x 2 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_cython/__pycache__
# -rw-r--r-- 1 root staff      148 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_cython/__pycache__/__init__.cpython-38.pyc
# drwxr-sr-x 2 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_cython/_credentials
# -rw-r--r-- 1 root staff   264440 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_cython/_credentials/roots.pem
# drwxr-sr-x 3 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_cython/_cygrpc
# -rw-r--r-- 1 root staff      577 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_cython/_cygrpc/__init__.py
# drwxr-sr-x 2 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_cython/_cygrpc/__pycache__
# -rw-r--r-- 1 root staff      156 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_cython/_cygrpc/__pycache__/__init__.cpython-38.pyc
# -rwxr-xr-x 1 root staff 13709752 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_cython/cygrpc.cpython-38-x86_64-linux-gnu.so
# -rw-r--r-- 1 root staff       26 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_grpcio_metadata.py
# -rw-r--r-- 1 root staff    25862 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_interceptor.py
# -rw-r--r-- 1 root staff    10417 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_observability.py
# -rw-r--r-- 1 root staff     4382 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_plugin_wrapping.py
# -rw-r--r-- 1 root staff     5805 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_runtime_protos.py
# -rw-r--r-- 1 root staff    50885 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_server.py
# -rw-r--r-- 1 root staff    24610 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_simple_stubs.py
# -rw-r--r-- 1 root staff     2758 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_typing.py
# -rw-r--r-- 1 root staff     7043 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/_utilities.py
# drwxr-sr-x 3 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio
# -rw-r--r-- 1 root staff     3160 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/__init__.py
# drwxr-sr-x 2 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/__pycache__
# -rw-r--r-- 1 root staff     2066 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/__pycache__/__init__.cpython-38.pyc
# -rw-r--r-- 1 root staff     8092 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/__pycache__/_base_call.cpython-38.pyc
# -rw-r--r-- 1 root staff    13824 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/__pycache__/_base_channel.cpython-38.pyc
# -rw-r--r-- 1 root staff    14505 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/__pycache__/_base_server.cpython-38.pyc
# -rw-r--r-- 1 root staff    21010 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/__pycache__/_call.cpython-38.pyc
# -rw-r--r-- 1 root staff    13442 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/__pycache__/_channel.cpython-38.pyc
# -rw-r--r-- 1 root staff    33456 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/__pycache__/_interceptor.cpython-38.pyc
# -rw-r--r-- 1 root staff     5390 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/__pycache__/_metadata.cpython-38.pyc
# -rw-r--r-- 1 root staff     8380 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/__pycache__/_server.cpython-38.pyc
# -rw-r--r-- 1 root staff      899 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/__pycache__/_typing.cpython-38.pyc
# -rw-r--r-- 1 root staff      446 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/__pycache__/_utils.cpython-38.pyc
# -rw-r--r-- 1 root staff     7560 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/_base_call.py
# -rw-r--r-- 1 root staff    13893 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/_base_channel.py
# -rw-r--r-- 1 root staff    12560 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/_base_server.py
# -rw-r--r-- 1 root staff    25356 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/_call.py
# -rw-r--r-- 1 root staff    22099 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/_channel.py
# -rw-r--r-- 1 root staff    41345 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/_interceptor.py
# -rw-r--r-- 1 root staff     5009 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/_metadata.py
# -rw-r--r-- 1 root staff     8931 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/_server.py
# -rw-r--r-- 1 root staff     1378 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/_typing.py
# -rw-r--r-- 1 root staff      821 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/aio/_utils.py
# drwxr-sr-x 3 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/beta
# -rw-r--r-- 1 root staff      577 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/beta/__init__.py
# drwxr-sr-x 2 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/beta/__pycache__
# -rw-r--r-- 1 root staff      145 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/beta/__pycache__/__init__.cpython-38.pyc
# -rw-r--r-- 1 root staff    18077 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/beta/__pycache__/_client_adaptations.cpython-38.pyc
# -rw-r--r-- 1 root staff     1363 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/beta/__pycache__/_metadata.cpython-38.pyc
# -rw-r--r-- 1 root staff    12122 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/beta/__pycache__/_server_adaptations.cpython-38.pyc
# -rw-r--r-- 1 root staff    10309 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/beta/__pycache__/implementations.cpython-38.pyc
# -rw-r--r-- 1 root staff     6426 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/beta/__pycache__/interfaces.cpython-38.pyc
# -rw-r--r-- 1 root staff     4462 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/beta/__pycache__/utilities.cpython-38.pyc
# -rw-r--r-- 1 root staff    27023 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/beta/_client_adaptations.py
# -rw-r--r-- 1 root staff     1638 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/beta/_metadata.py
# -rw-r--r-- 1 root staff    14611 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/beta/_server_adaptations.py
# -rw-r--r-- 1 root staff    12058 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/beta/implementations.py
# -rw-r--r-- 1 root staff     6082 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/beta/interfaces.py
# -rw-r--r-- 1 root staff     5005 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/beta/utilities.py
# drwxr-sr-x 4 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/experimental
# -rw-r--r-- 1 root staff     4103 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/experimental/__init__.py
# drwxr-sr-x 2 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/experimental/__pycache__
# -rw-r--r-- 1 root staff     3400 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/experimental/__pycache__/__init__.cpython-38.pyc
# -rw-r--r-- 1 root staff      641 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/experimental/__pycache__/gevent.cpython-38.pyc
# -rw-r--r-- 1 root staff     1488 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/experimental/__pycache__/session_cache.cpython-38.pyc
# drwxr-sr-x 3 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/experimental/aio
# -rw-r--r-- 1 root staff      660 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/experimental/aio/__init__.py
# drwxr-sr-x 2 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/experimental/aio/__pycache__
# -rw-r--r-- 1 root staff      248 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/experimental/aio/__pycache__/__init__.cpython-38.pyc
# -rw-r--r-- 1 root staff      973 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/experimental/gevent.py
# -rw-r--r-- 1 root staff     1533 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/experimental/session_cache.py
# drwxr-sr-x 6 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework
# -rw-r--r-- 1 root staff      577 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/__init__.py
# drwxr-sr-x 2 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/__pycache__
# -rw-r--r-- 1 root staff      150 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/__pycache__/__init__.cpython-38.pyc
# drwxr-sr-x 3 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/common
# -rw-r--r-- 1 root staff      577 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/common/__init__.py
# drwxr-sr-x 2 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/common/__pycache__
# -rw-r--r-- 1 root staff      157 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/common/__pycache__/__init__.cpython-38.pyc
# -rw-r--r-- 1 root staff      722 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/common/__pycache__/cardinality.cpython-38.pyc
# -rw-r--r-- 1 root staff      552 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/common/__pycache__/style.cpython-38.pyc
# -rw-r--r-- 1 root staff      988 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/common/cardinality.py
# -rw-r--r-- 1 root staff      824 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/common/style.py
# drwxr-sr-x 3 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/foundation
# -rw-r--r-- 1 root staff      577 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/foundation/__init__.py
# drwxr-sr-x 2 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/foundation/__pycache__
# -rw-r--r-- 1 root staff      161 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/foundation/__pycache__/__init__.cpython-38.pyc
# -rw-r--r-- 1 root staff      609 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/foundation/__pycache__/abandonment.cpython-38.pyc
# -rw-r--r-- 1 root staff     3167 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/foundation/__pycache__/callable_util.cpython-38.pyc
# -rw-r--r-- 1 root staff     7370 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/foundation/__pycache__/future.cpython-38.pyc
# -rw-r--r-- 1 root staff     2494 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/foundation/__pycache__/logging_pool.cpython-38.pyc
# -rw-r--r-- 1 root staff     1258 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/foundation/__pycache__/stream.cpython-38.pyc
# -rw-r--r-- 1 root staff     4518 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/foundation/__pycache__/stream_util.cpython-38.pyc
# -rw-r--r-- 1 root staff      878 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/foundation/abandonment.py
# -rw-r--r-- 1 root staff     3151 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/foundation/callable_util.py
# -rw-r--r-- 1 root staff     8373 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/foundation/future.py
# -rw-r--r-- 1 root staff     2248 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/foundation/logging_pool.py
# -rw-r--r-- 1 root staff     1377 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/foundation/stream.py
# -rw-r--r-- 1 root staff     4772 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/foundation/stream_util.py
# drwxr-sr-x 5 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces
# -rw-r--r-- 1 root staff      577 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/__init__.py
# drwxr-sr-x 2 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/__pycache__
# -rw-r--r-- 1 root staff      161 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/__pycache__/__init__.cpython-38.pyc
# drwxr-sr-x 3 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/base
# -rw-r--r-- 1 root staff      577 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/base/__init__.py
# drwxr-sr-x 2 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/base/__pycache__
# -rw-r--r-- 1 root staff      166 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/base/__pycache__/__init__.cpython-38.pyc
# -rw-r--r-- 1 root staff    13407 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/base/__pycache__/base.cpython-38.pyc
# -rw-r--r-- 1 root staff     1957 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/base/__pycache__/utilities.cpython-38.pyc
# -rw-r--r-- 1 root staff    12234 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/base/base.py
# -rw-r--r-- 1 root staff     2362 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/base/utilities.py
# drwxr-sr-x 3 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/face
# -rw-r--r-- 1 root staff      577 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/face/__init__.py
# drwxr-sr-x 2 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/face/__pycache__
# -rw-r--r-- 1 root staff      166 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/face/__pycache__/__init__.cpython-38.pyc
# -rw-r--r-- 1 root staff    40334 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/face/__pycache__/face.cpython-38.pyc
# -rw-r--r-- 1 root staff     5548 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/face/__pycache__/utilities.cpython-38.pyc
# -rw-r--r-- 1 root staff    39700 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/face/face.py
# -rw-r--r-- 1 root staff     6777 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpc/framework/interfaces/face/utilities.py
# drwxr-sr-x 2 root staff     4096 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpcio-1.70.0.dist-info
# -rw-r--r-- 1 root staff        4 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpcio-1.70.0.dist-info/INSTALLER
# -rw-r--r-- 1 root staff    29687 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpcio-1.70.0.dist-info/LICENSE
# -rw-r--r-- 1 root staff     3888 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpcio-1.70.0.dist-info/METADATA
# -rw-r--r-- 1 root staff     8558 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpcio-1.70.0.dist-info/RECORD
# -rw-r--r-- 1 root staff      148 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpcio-1.70.0.dist-info/WHEEL
# -rw-r--r-- 1 root staff        5 Nov 12 15:56 /usr/local/lib/python3.8/dist-packages/grpcio-1.70.0.dist-info/top_level.txt
# ----------------------------------------------------------------------
# + echo ----------------------------------------------------------------------
# + cd /home/ubuntu
# + DETS=install-details
# + mkdir -p install-details
# + mv usr-local-1-before-protobuf.txt usr-local-7-after-mininet-install.txt install-details
# + cd install-details
# Done, move to the next step

# %%
print('Cloning P4Kube on p4switch node')
p4project = f"""
    git clone https://github.com/gareging/P4Kube.git;
"""
slice.get_node('p4switch').execute(p4project)
print('Done, move to the next step')

# %%
print('Compile P4Kube P4 program')
commands = """
    pip3 install protobuf==3.20.*;
    pip3 install googleapis-common-protos;
    cd P4Kube;
    mkdir build;
    mkdir logs;
    mkdir pcaps;
    p4c-bm2-ss --p4v 16 --p4runtime-files build/p4kube.p4.p4info.txt -o build/p4kube.json p4kube.p4;
"""
slice.get_node('p4switch').execute(commands)
print('Done, move to the next step')

# %%
print('Generating the command to run the switch emulator')
p4switch = slice.get_node('p4switch')

# Port mapping: 1=master, 2=node1, ..., 11=node10, 12=client
bridge_names = ['ms'] + [f'n{i}s' for i in range(1, 11)] + ['cs']
port_map = {}

for port, bridge in enumerate(bridge_names, start=1):
    iface = p4switch.get_interface(network_name=bridge)
    linux_iface = iface.get_os_interface()
    port_map[port] = linux_iface

# Build the interface string
interface_args = ' '.join([f'--interface {port}@{iface}' for port, iface in port_map.items()])
command = f"cd ~/P4Kube; sudo simple_switch_grpc {interface_args} build/p4kube.json"

print('ssh to the switch through a terminal')
print('Run this command in tmux to keep it in background')
print()
print(command)
print()
print("Find the switch ssh command below:", slice.get_node(name="p4switch"))

# %%
print('Initializing the routing table of the P4Kube router')
commands = """
    cd P4Kube;
    python3 mycontroller.py;
"""
slice.get_node('p4switch').execute(commands)
print('All done! Now you can test connectivity between different nodes (e.g., ping client (21.0.0.2) from node1)')

# %%
print('Installing docker, Kubernetes on master and all nodes')
for node_name in ['master'] + [f'node{i}' for i in range(1, 11)]:
    node = slice.get_node(node_name)
    script = """
        # Docker install
        sudo apt update;
        sudo apt upgrade -y;
        sudo apt install docker.io -y;
        sudo systemctl enable docker;
        sudo systemctl start docker;

        # Kubernetes install
        cd /etc/apt && sudo mkdir -p keyrings && cd ~;
        echo "deb [signed-by=/etc/apt/keyrings/kubernetes-apt-keyring.gpg] https://pkgs.k8s.io/core:/stable:/v1.28/deb/ /" | sudo tee /etc/apt/sources.list.d/kubernetes.list;
        curl -fsSL https://pkgs.k8s.io/core:/stable:/v1.28/deb/Release.key | sudo gpg --dearmor -o /etc/apt/keyrings/kubernetes-apt-keyring.gpg;
        sudo apt-get update;
        sudo apt-get install -y kubelet kubeadm kubectl;
        sudo apt-mark hold kubeadm kubelet kubectl;
    """
    node.execute(script)
print('All done, move to the next step')

# %%
print('Setting up the cluster')
node = slice.get_node('master')
script = 'sudo kubeadm init --pod-network-cidr=10.244.0.0/16'
node.execute(script)
print('Update the token in the next cell based on the output above')

# %%
JOIN_COMMAND = 'sudo ' + '''kubeadm join ADD_TOKEN_AND_REMOVE_BACKSLASH '''
print(JOIN_COMMAND)

# %%
print('Joining all worker nodes to the cluster')
for node_name in [f'node{i}' for i in range(1, 11)]:
    node = slice.get_node(node_name)
    node.execute(JOIN_COMMAND)
print('All done, move to the next step')

# %%
print('Configuring networking for Kubernetes via Calico CNI')
node = slice.get_node('master')
script = ''' 
    sudo mkdir -p $HOME/.kube;
    sudo cp -i /etc/kubernetes/admin.conf $HOME/.kube/config;
    sudo chown $(id -u):$(id -g) $HOME/.kube/config;
    kubectl apply -f https://docs.projectcalico.org/manifests/calico.yaml;
    '''
node.execute(script)
print('Done on the master node')

''' Metric help fix '''
for node_name in [f'node{i}' for i in range(1, 11)]:
    node = slice.get_node(node_name)
    ip = f'{10+int(node_name[4:])}.0.0.2'

    script = f'''
        echo "KUBELET_EXTRA_ARGS=--node-ip={ip}" | sudo tee /etc/default/kubelet;
        sudo systemctl daemon-reexec;
        sudo systemctl daemon-reload;
        sudo systemctl restart kubelet;
    '''
    print(f"Configuring kubelet on {node_name}")
    node.execute(script)
print('All done, move to the next step')

# %%
print('Cloning P4Kube repo on the master node')
node = slice.get_node('master')
script = f'git clone https://github.com/gareging/P4Kube.git;'
node.execute(script)
print('All done, move to the next step')

# %%
# Setup the metrics and P4Kube plugin
node = slice.get_node('master')
script = '''
    wget -c https://go.dev/dl/go1.22.0.linux-amd64.tar.gz;
    sudo tar -C /usr/local/ -xzf go1.22.0.linux-amd64.tar.gz;
    export PATH=$PATH:/usr/local/go/bin;
    cd ~/P4Kube/
    kubectl apply -f metrics-server.yaml;
    kubectl patch deployment metrics-server -n kube-system --type 'json' -p '[{"op": "add", "path": "/spec/template/spec/containers/0/args/-", "value": "--kubelet-insecure-tls"}]';
    cd ~/P4Kube/kubectl-plugin;
    go get k8s.io/client-go@latest;
    go get k8s.io/metrics/pkg/client/clientset/versioned;
    go get k8s.io/apimachinery/pkg/util/diff@v0.34.0;
    cp main.go_LOAD_AWARE main.go;
    echo 'export PATH="/home/ubuntu/P4Kube/kubectl-plugin/:$PATH"' >> ~/.bashrc;
    go build;
'''
node.execute(script)

print('All done')

# %%
print("Find the master ssh command below:", slice.get_node(name="master"))
print('ssh into master, open tmux and run the command shown below')
print()
command='''cd ~/P4Kube/kubectl-plugin; export PATH=$PATH:/usr/local/go/bin; echo 'export PATH="/home/ubuntu/P4Kube/kubectl-plugin/:$PATH"' >> ~/.bashrc; go build; kubectl p4-loadbalancer;'''
print(command)

# %%
# Setup the deployment and service (optional)
print('Installing nginx deployment with 10 replicas')
node = slice.get_node('master')
script = '''     
    cd P4Kube/;
    kubectl create -f nginx-deployment.yaml;
    kubectl create -f nginx-service.yaml;
    kubectl patch svc ngnix-service -p '{"spec":{"externalTrafficPolicy":"Local"}}';
'''
node.execute(script)
print('All done, move to the next step')

# %%
print('On the P4Switch node, simple_switch_CLI will show 10 for the register replica_count (1 deployment)')
print('''To check, run 'register_read replica_count' in simple_switch_CLI''')
print("Find the switch ssh command below:", slice.get_node(name="p4switch"))

# %%
'''
This code will automatically replace the default html with a string "nodeX" to observe load balancing 
'''
for node_name in [f'node{i}' for i in range(1, 11)]:
    node = slice.get_node(node_name)
    script = '''
        podid=$(sudo crictl pods | awk '$0 ~ /nginx/ {print $1}');
        dockerid=$(sudo crictl ps | grep $podid | awk '{print $1}');
    '''
    script += f'''echo {node_name} | sudo crictl exec -i "$dockerid" sh -c 'cat > /usr/share/nginx/html/index.html';'''
    node.execute(script)
    print('Done on node', node_name)

# %%
print('Login to client and run curl 10.0.0.2 to verify load balancing')
print("Find the client ssh command below:", slice.get_node(name="client"))

# %%
print('Downscale the first deployment to 7 nodes')
node = slice.get_node('master')
script = 'kubectl scale --replicas=7 deployment nginx'
node.execute(script)
print('Check replica_count register on p4switch')

# %%
print('Install second nginx deployment with 3 replicas')
node = slice.get_node('master')
script = '''     
    cd P4Kube/;
    kubectl create -f nginx-deployment2.yaml;
    kubectl create -f nginx-service2.yaml;
    kubectl patch svc ngnix-service2 -p '{"spec":{"externalTrafficPolicy":"Local"}}';
'''
node.execute(script)
print('On the P4Switch node, replica_count register will show 7, 3 (1st and 2nd deployment)')
print('''To check, run 'register_read replica_count' in simple_switch_CLI''')
print(''' To test from the client, run curl 10.0.0.3 ''')

# %%
print('Install AIOQUIC server as the third deployment')
node = slice.get_node('master')
script = '''     
    cd P4Kube/;
    kubectl create -f quic.yaml;
    kubectl patch svc aioquic-http3-service -p '{"spec":{"externalTrafficPolicy":"Local"}}';
'''
node.execute(script)
print('All done')

# %%
# Testing QUIC (part 1)
print('Install QUIC dependencies on the client')
node = slice.get_node('client')
script = '''     
    sudo apt install libssl-dev python3.9 python3.9-venv python3.9-dev -y;
    sudo apt install python3-pip -y;
    pip3 install aioquic wsproto;
'''
node.execute(script)
print('All done')

# %%
# Testing QUIC (part 2)
print('Clone AIOQUIC repo')
node = slice.get_node('client')
script = '''     
    git clone https://github.com/aiortc/aioquic.git;
'''
node.execute(script)
print('All done')

# %%
# Testing QUIC (part 3)
print('Run QUIC request')
node = slice.get_node('client')
script = '''     
    cd aioquic/examples;
    python3 http3_client.py --insecure https://10.0.0.4:4433/;
'''
node.execute(script)
